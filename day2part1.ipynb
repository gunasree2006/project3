# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Iris_1.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1=df.copy(deep=True)
df1.isna().sum() #checking of null values
# Out:
# Id               0
# SepalLengthCm    2
# SepalWidthCm     3
# PetalLengthCm    4
# PetalWidthCm     6
# Species          0
# dtype: int64

# %%
df1.head(25)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            NaN           NaN  Iris-setosa
# 6    7            NaN           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           NaN            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df1["SepalLengthCm"].fillna(7.8, inplace=True)
df1.head(25)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            NaN           NaN  Iris-setosa
# 6    7            7.8           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           NaN            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df1["SepalLengthCm"].fillna(7.7, inplace=True)
df1.head(26)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            NaN           NaN  Iris-setosa
# 6    7            7.8           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           NaN            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
med=df1["SepalLengthCm"].median()
df1["SepalLengthCm"]=df1["SepalLengthCm"].fillna(med)
df1.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            NaN           NaN  Iris-setosa
# 6   7            7.8           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           NaN            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
me=df1["PetalLengthCm"].mean()
df1["PetalLengthCm"]=df1["PetalLengthCm"].fillna(me)
df1.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5       1.400000           0.2  Iris-setosa
# 1   2            4.9           3.0       1.400000           0.2  Iris-setosa
# 2   3            4.7           3.2       1.300000           0.2  Iris-setosa
# 3   4            4.6           3.1       1.500000           0.2  Iris-setosa
# 4   5            5.0           3.6       1.400000           0.2  Iris-setosa
# 5   6            5.4           3.9       3.820548           NaN  Iris-setosa
# 6   7            7.8           3.4       1.400000           0.3  Iris-setosa
# 7   8            5.0           3.4       1.500000           0.2  Iris-setosa
# 8   9            4.4           NaN       1.400000           0.2  Iris-setosa
# 9  10            4.9           3.1       1.500000           0.1  Iris-setosa

# %%
df1=df1.dropna(subset=["PetalLengthCm"],axis=0)
df1.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5       1.400000           0.2  Iris-setosa
# 1   2            4.9           3.0       1.400000           0.2  Iris-setosa
# 2   3            4.7           3.2       1.300000           0.2  Iris-setosa
# 3   4            4.6           3.1       1.500000           0.2  Iris-setosa
# 4   5            5.0           3.6       1.400000           0.2  Iris-setosa
# 5   6            5.4           3.9       3.820548           NaN  Iris-setosa
# 6   7            7.8           3.4       1.400000           0.3  Iris-setosa
# 7   8            5.0           3.4       1.500000           0.2  Iris-setosa
# 8   9            4.4           NaN       1.400000           0.2  Iris-setosa
# 9  10            4.9           3.1       1.500000           0.1  Iris-setosa
